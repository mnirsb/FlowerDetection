# %%
from __future__ import absolute_import,division,print_function,unicode_literals
import tensorflow as tf

import pandas as pd

# %%
CSV_COLUMN.NAMES = ['SepalLength','SepalWidth','PetalLength','PetalWidth','Species']
SPECIES =['Setosa','Versicolor','Virginica']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-c327cf4a45ec> in <module>
# ----> 1 CSV_COLUMN.NAMES = ['SepalLength','SepalWidth','PetalLength','PetalWidth','Species']
#       2 SPECIES =['Setosa','Versicolor','Virginica']
#
# NameError: name 'CSV_COLUMN' is not defined

# %%
train_path = tf.keras.utils.get_file("iris_training.csv","https://storage.googleapis.com/download.tensorflow.org/data/iris_training.csv")
test_path = tf.keras.utils.get_file("iris_test.csv","https://storage.googleapis.com/download.tensorflow.org/data/iris_test.csv")

train = pd.read_csv(train_path, names=CSV_COLUMN_NAMES, header=0)
test = pd.read_csv(train_path, names=CSV_COLUMN_NAMES, header=0)
train.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-a14170aaa121> in <module>
#       2 test_path = tf.keras.utils.get_file("iris_test.csv","https://storage.googleapis.com/download.tensorflow.org/data/iris_test.csv")
#       3
# ----> 4 train = pd.read_csv(train_path, names=CSV_COLUMN_NAMES, header=0)
#       5 test = pd.read_csv(train_path, names=CSV_COLUMN_NAMES, header=0)
#       6 train.head()
#
# NameError: name 'CSV_COLUMN_NAMES' is not defined

# %%
from __future__ import absolute_import,division,print_function,unicode_literals
import tensorflow as tf

import pandas as pd
CSV_COLUMN_NAMES = ['SepalLength','SepalWidth','PetalLength','PetalWidth','Species']
SPECIES =['Setosa','Versicolor','Virginica']
train_path = tf.keras.utils.get_file("iris_training.csv","https://storage.googleapis.com/download.tensorflow.org/data/iris_training.csv")
test_path = tf.keras.utils.get_file("iris_test.csv","https://storage.googleapis.com/download.tensorflow.org/data/iris_test.csv")

train = pd.read_csv(train_path, names=CSV_COLUMN_NAMES, header=0)
test = pd.read_csv(train_path, names=CSV_COLUMN_NAMES, header=0)
train.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth  Species
# 0          6.4         2.8          5.6         2.2        2
# 1          5.0         2.3          3.3         1.0        1
# 2          4.9         2.5          4.5         1.7        2
# 3          4.9         3.1          1.5         0.1        0
# 4          5.7         3.8          1.7         0.3        0

# %%
train_y = train.pop('Species')
test_y = test.pop('Species')

# %%
train.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth
# 0          6.4         2.8          5.6         2.2
# 1          5.0         2.3          3.3         1.0
# 2          4.9         2.5          4.5         1.7
# 3          4.9         3.1          1.5         0.1
# 4          5.7         3.8          1.7         0.3

# %%
train.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-ece5dc48e24a> in <module>
# ----> 1 train.shape()
#
# TypeError: 'tuple' object is not callable

# %%
train.shape
# Out:
# (120, 4)

# %%
train.describe()
# Out:
#        SepalLength  SepalWidth  PetalLength  PetalWidth
# count   120.000000  120.000000   120.000000  120.000000
# mean      5.845000    3.065000     3.739167    1.196667
# std       0.868578    0.427156     1.822100    0.782039
# min       4.400000    2.000000     1.000000    0.100000
# 25%       5.075000    2.800000     1.500000    0.300000
# 50%       5.800000    3.000000     4.400000    1.300000
# 75%       6.425000    3.300000     5.100000    1.800000
# max       7.900000    4.400000     6.900000    2.500000

# %%
def input_fn(features, labels, training = True, batch_size=256):
    dataset = tf.data.Dataset.from_tensor_slices((dict(features),labels))
    if training: 
        dataset = dataset.shuffle(1000).repeat()
    return dataset.batch(batch_size)
my_feature_columns = []
for key in train.keys():
    my_feature_columns.append(tf.feature_column.numeric_column(key=key))
    
classifier = tf.estimator.DNNClassifier(feature_columns = my_feature_columns,
                                       #two hidden layers of 30 and 10 nodes
                                       hidden_units=[30,10],
                                       # the model must choose between 3 classes
                                       n_classes=3)

classifier.train(input_fn=lambda: input_fn(train, train_y, training=True),
                steps=5000)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\shubham\AppData\Local\Temp\tmpuki5xw_o
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\shubham\\AppData\\Local\\Temp\\tmpuki5xw_o', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into C:\Users\shubham\AppData\Local\Temp\tmpuki5xw_o\model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 1.3486466, step = 0
# INFO:tensorflow:global_step/sec: 431.339
# INFO:tensorflow:loss = 1.0060751, step = 100 (0.240 sec)
# INFO:tensorflow:global_step/sec: 540.027
# INFO:tensorflow:loss = 0.9542091, step = 200 (0.183 sec)
# INFO:tensorflow:global_step/sec: 550.707
# INFO:tensorflow:loss = 0.92140067, step = 300 (0.176 sec)
# INFO:tensorflow:global_step/sec: 543.844
# INFO:tensorflow:loss = 0.8976107, step = 400 (0.184 sec)
# INFO:tensorflow:global_step/sec: 568.564
# INFO:tensorflow:loss = 0.87874424, step = 500 (0.184 sec)
# INFO:tensorflow:global_step/sec: 543.838
# INFO:tensorflow:loss = 0.85601956, step = 600 (0.184 sec)
# INFO:tensorflow:global_step/sec: 543.843
# INFO:tensorflow:loss = 0.83884203, step = 700 (0.184 sec)
# INFO:tensorflow:global_step/sec: 540.918
# INFO:tensorflow:loss = 0.8245605, step = 800 (0.177 sec)
# INFO:tensorflow:global_step/sec: 571.543
# INFO:tensorflow:loss = 0.8047968, step = 900 (0.183 sec)
# INFO:tensorflow:global_step/sec: 544.792
# INFO:tensorflow:loss = 0.7932133, step = 1000 (0.176 sec)
# INFO:tensorflow:global_step/sec: 567.606
# INFO:tensorflow:loss = 0.783967, step = 1100 (0.184 sec)
# INFO:tensorflow:global_step/sec: 537.746
# INFO:tensorflow:loss = 0.7617912, step = 1200 (0.178 sec)
# INFO:tensorflow:global_step/sec: 543.29
# INFO:tensorflow:loss = 0.7520578, step = 1300 (0.194 sec)
# INFO:tensorflow:global_step/sec: 557.159
# INFO:tensorflow:loss = 0.74276006, step = 1400 (0.169 sec)
# INFO:tensorflow:global_step/sec: 508.586
# INFO:tensorflow:loss = 0.7221511, step = 1500 (0.205 sec)
# INFO:tensorflow:global_step/sec: 543.846
# INFO:tensorflow:loss = 0.7129985, step = 1600 (0.184 sec)
# INFO:tensorflow:global_step/sec: 543
(0.184 sec)
# INFO:tensorflow:global_step/sec: 543.732
# INFO:tensorflow:loss = 0.49239942, step = 4200 (0.176 sec)
# INFO:tensorflow:global_step/sec: 568.685
# INFO:tensorflow:loss = 0.49286503, step = 4300 (0.184 sec)
# INFO:tensorflow:global_step/sec: 543.838
# INFO:tensorflow:loss = 0.4833279, step = 4400 (0.176 sec)
# INFO:tensorflow:global_step/sec: 543.842
# INFO:tensorflow:loss = 0.4752239, step = 4500 (0.184 sec)
# INFO:tensorflow:global_step/sec: 458.875
# INFO:tensorflow:loss = 0.462088, step = 4600 (0.219 sec)
# INFO:tensorflow:global_step/sec: 465.832
# INFO:tensorflow:loss = 0.4713741, step = 4700 (0.222 sec)
# INFO:tensorflow:global_step/sec: 521.19
# INFO:tensorflow:loss = 0.46087927, step = 4800 (0.184 sec)
# INFO:tensorflow:global_step/sec: 568.68
# INFO:tensorflow:loss = 0.44347435, step = 4900 (0.184 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 5000...
# INFO:tensorflow:Saving checkpoints for 5000 into C:\Users\shubham\AppData\Local\Temp\tmpuki5xw_o\model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 5000...
# INFO:tensorflow:Loss for final step: 0.44762868.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-08-29T16:09:01Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\shubham\AppData\Local\Temp\tmpuki5xw_o\model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.40535s
# INFO:tensorflow:Finished evaluation at 2020-08-29-16:09:01
# INFO:tensorflow:Saving dict for global step 5000: accuracy = 0.96666664, average_loss = 0.4524143, global_step = 5000, loss = 0.4524143
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 5000: C:\Users\shubham\AppData\Local\Temp\tmpuki5xw_o\model.ckpt-5000
#
# Test set Accuracy: {accuracy:0.3f}
# ,format(**eval_result)

# %%
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-08-29T16:07:00Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\shubham\AppData\Local\Temp\tmpyndd6ih9\model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.38763s
# INFO:tensorflow:Finished evaluation at 2020-08-29-16:07:01
# INFO:tensorflow:Saving dict for global step 5000: accuracy = 0.85833335, average_loss = 0.4324732, global_step = 5000, loss = 0.4324732
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 5000: C:\Users\shubham\AppData\Local\Temp\tmpyndd6ih9\model.ckpt-5000
#
# Test set Accuracy: {accuracy:0.3f}
# .format(**eval_result)

# %%
eval_result=classifier.evaluate(input_fn=lambda: input_fn(test, test_y, training=False))
print('\nTest set Accuracy: {accuracy:0.3f}\n'.format(**eval_result))
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-08-29T16:09:39Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\shubham\AppData\Local\Temp\tmpuki5xw_o\model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.38408s
# INFO:tensorflow:Finished evaluation at 2020-08-29-16:09:39
# INFO:tensorflow:Saving dict for global step 5000: accuracy = 0.96666664, average_loss = 0.4524143, global_step = 5000, loss = 0.4524143
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 5000: C:\Users\shubham\AppData\Local\Temp\tmpuki5xw_o\model.ckpt-5000
#
# Test set Accuracy: 0.967

# %%
def input_fn(features, batch_size=256):
    return tf.data.Dataset.from_tensor_slices(dict(features)).batch(batch_sizes)

features = ['SepalLength','SepalWidth','PetalLength','PetalWidth']
predict = {}

print('Please Type numeric values as prompted.')
for feature in features:
    valid = True
    while valid:
        val = input(feature +": ")
        if not val.isdigit(): valid = False
            
    predict[feature] = [float(val)]
predictions = classifier.predict(input_fn = lambda: input_fn(predict))
for prod_dict in predictions:
    class_id = pred_dict['class_ids'][0]
    possibility = pred_dict['probabilities'][class_id]
    
    print('Prediction is "{}"({:.1f}%'.format(SPECIES[class_id],100*probability))
# Out:
# Please Type numeric values as prompted.
# SepalLength: 2
# SepalLength: 2
# SepalLength: 24
# SepalLength: 626
# SepalLength: 56
# SepalLength: 6266
# SepalLength: 6262
# SepalLength: 2626
# SepalLength: 262626
# SepalLength: 22
# SepalLength: 2.4
# SepalWidth: 2.8
# PetalLength: 3.2
# PetalWidth: 2.6
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-5c8c478c2482> in <module>
#      14     predict[feature] = [float(val)]
#      15 predictions = classifier.predict(input_fn = lambda: input_fn(predict))
# ---> 16 for prod_dict in predictions:
#      17     class_id = pred_dict['class_ids'][0]
#      18     possibility = pred_dict['probabilities'][class_id]
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow_estimator\python\estimator\estimator.py in predict(self, input_fn, predict_keys, hooks, checkpoint_path, yield_single_examples)
#     608         tf.compat.v1.random.set_random_seed(self._config.tf_random_seed)
#     609         self._create_and_assert_global_step(g)
# --> 610         features, input_hooks = self._get_features_from_input_fn(
#     611             input_fn, ModeKeys.PREDICT)
#     612         estimator_spec = self._call_model_fn(features, None, ModeKeys.PREDICT,
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow_estimator\python\estimator\estimator.py in _get_features_from_input_fn(self, input_fn, mode)
#    1005   def _get_features_from_input_fn(self, input_fn, mode):
#    1006     """Extracts the `features` from return values of `input_fn`."""
# -> 1007     result = self._call_input_fn(input_fn, mode)
#    1008     result, _, hooks = estimator_util.parse_input_fn_result(result)
#    1009     self._validate_features_in_predict_input(result)
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow_estimator\python\estimator\estimator.py in _call_input_fn(self, input_fn, mode, input_context)
#    1128       kwargs['input_context'] = input_context
#    1129     with tf.compat.v1.device('/cpu:0'):
# -> 1130       return input_fn(**kwargs)
#    1131
#    1132   def _call_model_fn(self, features, labels, mode, config):
#
# <ipython-input-25-5c8c478c2482> in <lambda>()
#      13
#      14     predict[feature] = [float(val)]
# ---> 15 predictions = classifier.predict(input_fn = lambda: input_fn(predict))
#      16 for prod_dict in predictions:
#      17     class_id = pred_dict['class_ids'][0]
#
# <ipython-input-25-5c8c478c2482> in input_fn(features, batch_size)
#       1 def input_fn(features, batch_size=256):
# ----> 2     return tf.data.Dataset.from_tensor_slices(dict(features)).batch(batch_sizes)
#       3
#       4 features = ['SepalLength','SepalWidth','PetalLength','PetalWidth']
#       5 predict = {}
#
# NameError: name 'batch_sizes' is not defined

# %%
def input_fn(features, batch_size=256):
    return tf.data.Dataset.from_tensor_slices(dict(features)).batch(batch_sizes)

features = ['SepalLength','SepalWidth','PetalLength','PetalWidth']
predict = {}

print('Please Type numeric values as prompted.')
for feature in features:
    valid = True
    while valid:
        val = input(feature +": ")
        if not val.isdigit(): valid = False
            
    predict[feature] = [float(val)]
predictions = classifier.predict(input_fn = lambda: input_fn(predict))
for pred_dict in predictions:
    class_id = pred_dict['class_ids'][0]
    probability = pred_dict['probabilities'][class_id]
    
    print('Prediction is "{}"({:.1f}%'.format(SPECIES[class_id],100*probability))
# Out:
# Please Type numeric values as prompted.
# SepalLength: 2.4
# SepalWidth: 2.6
# PetalLength: 6.5
# PetalWidth: 6.4
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-889c6b3b2c3a> in <module>
#      14     predict[feature] = [float(val)]
#      15 predictions = classifier.predict(input_fn = lambda: input_fn(predict))
# ---> 16 for pred_dict in predictions:
#      17     class_id = pred_dict['class_ids'][0]
#      18     probability = pred_dict['probabilities'][class_id]
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow_estimator\python\estimator\estimator.py in predict(self, input_fn, predict_keys, hooks, checkpoint_path, yield_single_examples)
#     608         tf.compat.v1.random.set_random_seed(self._config.tf_random_seed)
#     609         self._create_and_assert_global_step(g)
# --> 610         features, input_hooks = self._get_features_from_input_fn(
#     611             input_fn, ModeKeys.PREDICT)
#     612         estimator_spec = self._call_model_fn(features, None, ModeKeys.PREDICT,
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow_estimator\python\estimator\estimator.py in _get_features_from_input_fn(self, input_fn, mode)
#    1005   def _get_features_from_input_fn(self, input_fn, mode):
#    1006     """Extracts the `features` from return values of `input_fn`."""
# -> 1007     result = self._call_input_fn(input_fn, mode)
#    1008     result, _, hooks = estimator_util.parse_input_fn_result(result)
#    1009     self._validate_features_in_predict_input(result)
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow_estimator\python\estimator\estimator.py in _call_input_fn(self, input_fn, mode, input_context)
#    1128       kwargs['input_context'] = input_context
#    1129     with tf.compat.v1.device('/cpu:0'):
# -> 1130       return input_fn(**kwargs)
#    1131
#    1132   def _call_model_fn(self, features, labels, mode, config):
#
# <ipython-input-29-889c6b3b2c3a> in <lambda>()
#      13
#      14     predict[feature] = [float(val)]
# ---> 15 predictions = classifier.predict(input_fn = lambda: input_fn(predict))
#      16 for pred_dict in predictions:
#      17     class_id = pred_dict['class_ids'][0]
#
# <ipython-input-29-889c6b3b2c3a> in input_fn(features, batch_size)
#       1 def input_fn(features, batch_size=256):
# ----> 2     return tf.data.Dataset.from_tensor_slices(dict(features)).batch(batch_sizes)
#       3
#       4 features = ['SepalLength','SepalWidth','PetalLength','PetalWidth']
#       5 predict = {}
#
# NameError: name 'batch_sizes' is not defined

# %%
def input_fn(features, batch_sizes=256):
    return tf.data.Dataset.from_tensor_slices(dict(features)).batch(batch_sizes)

features = ['SepalLength','SepalWidth','PetalLength','PetalWidth']
predict = {}

print('Please Type numeric values as prompted.')
for feature in features:
    valid = True
    while valid:
        val = input(feature +": ")
        if not val.isdigit(): valid = False
            
    predict[feature] = [float(val)]
 
predictions = classifier.predict(input_fn = lambda: input_fn(predict))
for pred_dict in predictions:
    class_id = pred_dict['class_ids'][0]
    probability = pred_dict['probabilities'][class_id]
    
    print('Prediction is "{}"({:.1f}%)'.format(SPECIES[class_id],100*probability))
# Out:
# Please Type numeric values as prompted.
# SepalLength: 5.1
# SepalWidth: 3.3
# PetalLength: 1.7
# PetalWidth: 0.5
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\shubham\AppData\Local\Temp\tmpuki5xw_o\model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Prediction is "Setosa"(78.1%)
